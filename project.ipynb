# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c7a9dc6c-b7d8-4da8-97fd-111d25c4711e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7a9dc6c-b7d8-4da8-97fd-111d25c4711e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data=pd.read_csv('housing.csv') ## Load the original data set into a pandas DataFrame

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# **1**. **What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.**

# %%
###to calculate the average median income, we can extract the "median_income" column from the dataset and compute the mean.

avg=(df['median_income'].sum())/(len(df['median_income'])) #sum of all median incomeand divide it by total no of median incomes.
avg
# Out:
# 3.8706710029069766

# %%
avg=df['median_income'].mean()
avg
# Out:
# 3.8706710029069766

# %%
import matplotlib.pyplot as plt ##for using plot function in matplotlib
plt.hist(df['median_income'],color='skyblue', edgecolor='black',bins=20)
##To visualize the distribution of a single variable, we can plot a histogram. This will show the frequency distribution of the "median_income" values.
plt.xlabel('median_income') #to give name to x-axis
plt.ylabel('frequency') #label for Y-axis
plt.title('Distribution of data')#title for plot
plt.show()
###rightskew

# %% [markdown]
# **2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.**

# %%
plt.hist(df['housing_median_age'],color='green',edgecolor='black',bins=20) #the number of intervals or categories into which the data is divided.
##To visualize the distribution of the "housing_median_age" variable, a histogram would be an appropriate plot.
##This type of plot will show the frequency distribution of the different age values.
plt.xlabel('housing_median_age')#x-axis label
plt.ylabel('frequency')#label for y-axis (count of occurrences) on the y-axis
plt.title('Distribution of housing_median_age')#title for plot
plt.show()

# %% [markdown]
# **3. Show with the help of visualization, how median_income and median_house_values are related?**
# **bold text**

# %%
a=df['median_income']
b=df['median_house_value']
#plt.figure(figsize=(10,6)) to adjust the plot size

plt.scatter(a,b,marker = 'o', edgecolor = 'c', facecolor = 'k', s = 20)
plt.grid(ls='dashed',lw=2,c='r')

###This plot will show how the values of these two variables are distributed and if there is any correlation between them.

plt.xlabel('median_income')#for labeling purpose
plt.ylabel('median_house_value')
plt.title('relation between median_income and median_H_value')
plt.show()
##Observe the general direction of the points. they are moving from the bottom left to the top right, it indicates a positive relationship between the variables.

# %%
import seaborn as sns
sns.set()
#plt.figure(figsize=(10,6)) to adjust the plot size

sns.relplot(x='median_income',y='median_house_value',data=df,kind='scatter')
###This plot will show how the values of these two variables are distributed and if there is any correlation between them.

plt.show()
##Observe the general direction of the points. they are moving from the bottom left to the top right, it indicates a positive relationship between the variables.

# %%
df['median_income'].corr(df['median_house_value'])
# Out:
# 0.688075207958548

# %% [markdown]
# **4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.**
#
# **bold text**

# %%
# Create a new dataset by dropping rows where 'total_bedrooms' is NaN
new_df = df.dropna(subset=['total_bedrooms'])

# Reset the index of the new dataset
new_df.reset_index(drop=True, inplace=True) ##old index is not added as a new column in the new dataset.


# Print the new dataset`new_df`is printed, where the "total_bedrooms" values are available.
print(new_df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20428    -121.09     39.48                  25         1665           374.0
# 20429    -121.21     39.49                  18          697           150.0
# 20430    -121.22     39.43                  17         2254           485.0
# 20431    -121.32     39.43                  18         1860           409.0
# 20432    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
mean_value=df['total_bedrooms'].mean() ## Calculate the mean value of the total_bedrooms column
print(mean_value)
new_df=df.fillna(df['total_bedrooms'].mean()) ## Replace the missing values in the total_bedrooms column with the mean value

df['total_bedrooms']==537.8705525375618
new_df.to_csv('new_dataset.csv')#create new dataset
new_df
# Out:
# 537.8705525375618
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# **6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.**

# %%
import pandas as pd

# Define the calculate_median function
def calculate_median(data):
    sorted_data = sorted(data)
    n = len(sorted_data)

    if n % 2 == 0:
        median = (sorted_data[n//2 - 1] + sorted_data[n//2]) / 2
    else:
        median = sorted_data[n//2]

    return median
df = pd.DataFrame(data)

# Calculate the median for each numeric column
for column in df.select_dtypes(include=[float, int]).columns:
    median_value = calculate_median(df[column])
    print(f"Median {column}: {median_value}")
# Out:
# Median longitude: -118.49
# Median latitude: 34.26
# Median housing_median_age: 29.0
# Median total_rooms: 2127.0
# Median total_bedrooms: 429.0
# Median population: 1166.0
# Median households: 409.0
# Median median_income: 3.5347999999999997
# Median median_house_value: 179700.0

# %% [markdown]
# **7. Plot latitude versus longitude and explain your observations.**

# %%
df.dropna(inplace=True)
a=df['longitude']
b=df['latitude']

#plt.figure(figsize=(10,6)) to adjust the plot size
plt.scatter(a,b,marker = 'o', edgecolor = 'c', facecolor = 'k', s = 20)

plt.grid(ls='dashed',lw=2,c='r')

#This plot will show how the values of these two variables are distributed and if there is any correlation between them.
plt.xlabel('longitude')#for labeling purpose
plt.ylabel('latitude')
plt.title('relation between latitude & longitude')
plt.show()

#as latitude increases then longitude decreases and vice versa.

# %%
sns.relplot(x='longitude',y='latitude',data=df,kind='scatter')
plt.show()

# %% [markdown]
# **8. Create a data set for which the ocean_proximity is ‘Near ocean’.**
#
# :

# %%
df1=df[df['ocean_proximity']=='NEAR OCEAN']
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# **9. Find the mean and median of the median income for the data set created in question 8.**

# %%
mean=df1['median_income'].mean()
print(mean)
median=df1['median_income'].median()
median
# Out:
# 4.0057848006019565
# 3.64705

# %% [markdown]
# **10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.**

# %%
df['total_bedrooms'].isna()
len(df['total_bedrooms'])
def fun(total_bedrooms):
  if total_bedrooms <= 10 :
      return 'small'
  elif total_bedrooms < 1000:
    return 'medium'
  else:
    return 'large'
n=len(df['total_bedrooms'])


df['total_bedroom_size']=df['total_bedrooms'].apply(fun)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
